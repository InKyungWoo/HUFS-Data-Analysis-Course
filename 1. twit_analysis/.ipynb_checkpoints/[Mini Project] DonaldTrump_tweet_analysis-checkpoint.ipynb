# %%
# 필요한 라이브러리 설치

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import matplotlib.pylab as pylab
from wordcloud import WordCloud, STOPWORDS

# %%
# 캐글에서 다운받은 데이터셋 파일 읽어오기

df = pd.read_csv('realdonaldtrump.csv')
df.head()    # 상위 5행 확인
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 09:07:28
#
#    retweets  favorites mentions hashtags
# 0       510        917      NaN      NaN
# 1        34        267      NaN      NaN
# 2        13         19      NaN      NaN
# 3        11         26      NaN      NaN
# 4      1375       1945      NaN      NaN

# %%
# 3. 데이터 전처리 및 시각화

# 데이터프레임 열 타입, 결측값 개수 확인

df.info()

# mentions, hashtags 칼럼에 결측값 있음을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43352 entries, 0 to 43351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         43352 non-null  int64
#  1   link       43352 non-null  object
#  2   content    43352 non-null  object
#  3   date       43352 non-null  object
#  4   retweets   43352 non-null  int64
#  5   favorites  43352 non-null  int64
#  6   mentions   20386 non-null  object
#  7   hashtags   5583 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 2.6+ MB

# %%
# 결측치 NaN을 공백으로 대체

df1 = df.replace(np.nan, '', regex=True)
df1.head()
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 09:07:28
#
#    retweets  favorites mentions hashtags
# 0       510        917
# 1        34        267
# 2        13         19
# 3        11         26
# 4      1375       1945

# %%
# df1의 칼럼 정보 확인

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43352 entries, 0 to 43351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         43352 non-null  int64
#  1   link       43352 non-null  object
#  2   content    43352 non-null  object
#  3   date       43352 non-null  object
#  4   retweets   43352 non-null  int64
#  5   favorites  43352 non-null  int64
#  6   mentions   43352 non-null  object
#  7   hashtags   43352 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 2.6+ MB

# %%
# 3-1. 연도별 tweet 수

# 필요한 칼럼, 데이터 추출
date_split = df1["date"].str.split("-").str
df1["year"] = date_split.get(0)
df1
# Out:
#                         id                                               link  \
# 0               1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1               1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2               1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3               1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4               1773561338  https://twitter.com/realDonaldTrump/status/177...
# ...                    ...                                                ...
# 43347  1273405198698975232  https://twitter.com/realDonaldTrump/status/127...
# 43348  1273408026968457216  https://twitter.com/realDonaldTrump/status/127...
# 43349  1273442195161387008  https://twitter.com/realDonaldTrump/status/127...
# 43350  1273442469066276864  https://twitter.com/realDonaldTrump/status/127...
# 43351  1273442528411385858  https://twitter.com/realDonaldTrump/status/127...
#
#                                                  content                 date  \
# 0      Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1      Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2      Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3      New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4      "My persona will never be that of a wallflower...  2009-05-12 09:07:28
# ...                                                  ...                  ...
# 43347  Joe Biden was a TOTAL FAILURE in Government. H...  2020-06-17 19:00:32
# 43348  Will be interviewed on @ seanhannity tonight a...  2020-06-17 19:11:47
# 43349                         pic.twitter.com/3lm1spbU8X  2020-06-17 21:27:33
# 43350                         pic.twitter.com/vpCE5MadUz  2020-06-17 21:28:38
# 43351                         pic.twitter.com/VLlc0BHW41  2020-06-17 21:28:52
#
#        retweets  favorites      mentions hashtags  year
# 0           510        917                         2009
# 1            34        267                         2009
# 2            13         19                         2009
# 3            11         26                         2009
# 4          1375       1945                         2009
# ...         ...        ...           ...      ...   ...
# 43347     23402     116377                         2020
# 43348     11810      56659  @seanhannity           2020
# 43349      4959      19344                         2020
# 43350      4627      17022                         2020
# 43351      3951      14344                         2020
#
# [43352 rows x 9 columns]

# %%
# 연도별 집계

df1['year'].value_counts()
# Out:
# 2013    8203
# 2015    7707
# 2014    6001
# 2019    4590
# 2012    4193
# 2016    3945
# 2018    3001
# 2020    2413
# 2017    2231
# 2011     869
# 2010     143
# 2009      56
# Name: year, dtype: int64

# %%
# 그래프로 나타내기

year_data = df1['year'].value_counts()
year_data = year_data.sort_index()    # 연도 순으로 sorting
year_data
# Out:
# 2009      56
# 2010     143
# 2011     869
# 2012    4193
# 2013    8203
# 2014    6001
# 2015    7707
# 2016    3945
# 2017    2231
# 2018    3001
# 2019    4590
# 2020    2413
# Name: year, dtype: int64

# %%
# 평균치 구하기
year_data.mean()
# Out:
# 3612.6666666666665

# %%
plt.figure(figsize= (10,7))
plt.bar(year_data.index, year_data, alpha=0.8)         # 바 그래프 출력
plt.plot(year_data.index, year_data, color='b',
         linestyle='--', marker='o')        # 선 그래프 출력
plt.title('Frequency of Tweets per Year',fontsize=20)   # 그래프의 제목
plt.xticks(rotation=0)
plt.show()

# %%
# 3-2. 시간대 별 트윗 수와 트윗 반응(retweet, favorites) 

# date 칼럼에서 시간 추출
df1['time'] = df1['date'].str[-8:-6]
time_data = df1['time'].value_counts()    # 시간대별 집계
time_data
# Out:
# 14    3284
# 15    3274
# 13    2791
# 08    2708
# 07    2591
# 09    2547
# 06    2346
# 10    2263
# 21    2207
# 12    2113
# 11    2113
# 20    2080
# 19    1875
# 16    1842
# 17    1740
# 18    1629
# 05    1436
# 22    1404
# 23     917
# 04     623
# 03     454
# 00     431
# 01     350
# 02     334
# Name: time, dtype: int64

# %%
plt.figure(figsize= (15,9))
plt.bar(time_data.index, time_data, alpha=0.8)  # 바 그래프 출력
plt.title('Frequency of Tweets per Hour',fontsize=20)   
plt.xticks(rotation=0)
plt.show()

# %%
# 시간대별 retweets 수 집계

retweets_time = df1.groupby('time')['retweets'].sum()
retweets_time
# Out:
# time
# 00     1324059
# 01      437712
# 02      568397
# 03      585081
# 04     1660199
# 05    13421496
# 06    23162504
# 07    27467973
# 08    22107072
# 09    19316064
# 10    12071374
# 11    10470400
# 12    10311846
# 13    11707162
# 14    13095909
# 15    13890305
# 16    13262639
# 17    14958848
# 18    11662048
# 19    11617615
# 20    12464492
# 21    12247508
# 22     9279985
# 23     4499487
# Name: retweets, dtype: int64

# %%
plt.figure(figsize= (10,7))
plt.plot(retweets_time.index, retweets_time, color='b',
         linestyle='--', marker='o')           
plt.title('Frequency of Retweets per Hour',fontsize=20)   
plt.xticks(rotation=0)
plt.show()

# %%
# 시간대별 favorites 수 집계

favorites_time = df1.groupby('time')['favorites'].sum()
favorites_time
# Out:
# time
# 00      5298696
# 01      1789804
# 02      2197605
# 03      2437008
# 04      6067142
# 05     56704920
# 06    102829698
# 07    121529818
# 08     94952005
# 09     83652803
# 10     49743832
# 11     43133145
# 12     42006326
# 13     45874357
# 14     53355658
# 15     55413491
# 16     55552243
# 17     65048232
# 18     47639409
# 19     47669807
# 20     49150508
# 21     49451296
# 22     37555268
# 23     18253779
# Name: favorites, dtype: int64

# %%
plt.figure(figsize= (10,7))
plt.plot(favorites_time.index, favorites_time, color='r',
         linestyle='--', marker='s')           
plt.title('Frequency of Favorites per Hour', fontsize=20)   
plt.xticks(rotation=0)
plt.show()

# %%
# 데이터 시각화

plt.figure(figsize= (15,9))
# 시간대별 트윗 수 (%)
plt.bar(time_data.index, time_data/time_data.max(), alpha=0.5, label='Tweets')  
# 시간대별 리트윗 수 (%)
plt.plot(retweets_time.index, retweets_time/retweets_time.max(), color='b',
         linestyle='--', marker='o',label='retweets')          
# 시간대별 좋아요 수 (%)
plt.plot(favorites_time.index, favorites_time/favorites_time.max(), color='r',
         linestyle='--', marker='s',label='favorites') 

plt.title('Frequency of Tweets and Responses per Hour',fontsize=20)   
plt.xticks(rotation=0)
plt.legend(fontsize=15)
plt.show()

# %%
# 3-3. retweets와 favorites 사이의 상관 관계

# 필요한 칼럼 추출
re_fav = df.loc[:,'retweets':'favorites']
re_fav.corr()
# Out:
#            retweets  favorites
# retweets   1.000000   0.946925
# favorites  0.946925   1.000000

# %%
# 상관도 분석 (Correlation) 시각화
plt.figure(figsize=(10,10))

sns.heatmap(re_fav.corr(), annot=True, 
    fmt = '.2f', linewidths=.5, cmap='Blues',
    cbar_kws={"shrink": .5}, vmin = -1,vmax = 1 )
# Out:
# <AxesSubplot:>

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: scipy>=1.1 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: pandas>=0.21 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.3.4)
# Requirement already satisfied: patsy>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.21->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.21->statsmodels) (2021.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(figsize=(10,7))
plt.scatter(re_fav['retweets'],re_fav['favorites'],s=5)

# %%
# 산점도 분석 (Scatter Plot) 시각화

x =  df1['retweets']
y = df1['favorites']

# 추세선을 위한 계산 - 1차원의 polynomial(다항식)을 계산
z = np.polyfit(x, y, 1) # (X,Y,차원) 정의
p = np.poly1d(z) # 1차원 다항식에 대한 연산을 캡슐화

# 그래프 그리기
pylab.figure(figsize=(10,7))
pylab.plot(x,y,'o') #산점도 'o'
pylab.plot(x,p(x),"r--")

# %%
# 3-4. 가장 많이 사용된 hashtag 분석

df = pd.read_csv('realdonaldtrump.csv')
hashtag_df = df[['hashtags']]
hashtag_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43352 entries, 0 to 43351
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hashtags  5583 non-null   object
# dtypes: object(1)
# memory usage: 338.8+ KB

# %%
# 결측치 있는 행 제거

hashtag_df = hashtag_df.dropna(axis=0)
hashtag_df
# Out:
#           hashtags
# 188     #EvanForSI
# 235    #TrumpRoast
# 236    #TrumpRoast
# 237    #TrumpRoast
# 239    #TrumpRoast
# ...            ...
# 43283  #IASENhttps
# 43286   #GA06https
# 43299  #NHSENhttps
# 43302        #MAGA
# 43341   #NY27https
#
# [5583 rows x 1 columns]

# %%
hashtag_df['hashtags'] = hashtag_df['hashtags'].str.replace('#','')
hashtag_df
# Out:
#          hashtags
# 188     EvanForSI
# 235    TrumpRoast
# 236    TrumpRoast
# 237    TrumpRoast
# 239    TrumpRoast
# ...           ...
# 43283  IASENhttps
# 43286   GA06https
# 43299  NHSENhttps
# 43302        MAGA
# 43341   NY27https
#
# [5583 rows x 1 columns]

# %%
hashtag_data = ''
for data in hashtag_df['hashtags']:
    hashtag_data =  hashtag_data + ' ' + data

print(hashtag_data)
# Out:
#  EvanForSI TrumpRoast TrumpRoast TrumpRoast TrumpRoast 1 Indy500 trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog VEGASusa11,MissUSA trumpvlog,celebrityapprenticefinale MissUSA,VEGASusa11 trumpvlog trumpvlog trumpvlog trumpvlog trumpdocumentary trumpvlog 1 trumpvlog trumpvlog TeenUSA trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog Apprentice Apprentice Apprentice Apprentice trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog MissUniverse trumpvlog trumpvlog Solyndra sparknb trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog trumpvlog thedailyshow trumpvlog trumpvlog trumpvlog trumpvlog TimeToGetTough TimeToGetTough TImeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough 1 TimeToGetTough TimeToGetTough 1 TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough trumpvlog TimeToGetTough TimeToGetTough 1,TimeToGetTough 1 TimeToGetTough,1 TimeToGetTough trumpvlog TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetToughhttp TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough 1 TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TImeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGet TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough TimeToGetTough C21SuperBowl TimeToGetTough TimeToGetTough C21 TimeToGetTough TimeToGetTough TimeToGetTough SuperBowl Superbowl OneTermFund TimeToGetTough TrumpQandA TrumpQandA sayfie TimeToGetTough TimeToGetTough 1,TimeToGetTough trumpvlog,CelebApprentice TrumpQ CelebApprentice TimeToGetToughhttp CNNDebate Nadarkhani CNNDebate CNNDebate Nadarkhani Oscars TimeToGetTough CelebApprentice pga,golf TrumpTuesday bluemonsterhttp CelebApprentice CelebApprentice,Apprentice CelebApprentice CelebApprentice trumpvlog freespeech ObamaCare ObamaCare TheArtofTheDeal TheArtofTheDeal CelebApprenticehttp TimeToGetTough TrumpTuesday TheArtofTheDeal CelebApprentice,trumpvlog CelebrityApprentice rockhall2012 Success rozandmocha TrumpTuesday CelebApprenticehttp CelebApprentice PainatthePump Success CelebrityApprentice Success 1 trumpvlog TrumpTowers CelebrityApprentice TrumpTowers TheArtofTheDeal TheArtofTheDeal CelebApprentice CelebApprentice TrumpTuesday Success WHCD WHCD WHCD CelebrityApprentice SweepsTweet SweepsTweet SweepsTweet SweepsTweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet sweepstweet CelebrityApprentice sweepstweet sweepstweet sweepstweet sweepstweet NBC,SweepsTweet TrumpTuesday TheArtofTheDeal DWTS MidasTouch CelebrityApprentice TrumpTuesday DWTS,01 CelebrityApprentice CelebrityApprentice CelebrityApprentice CelebrityApprentice CelebrityApprentice CelebrityApprentice Mets trumpvlog CelebrityApprentice GOP CallMeMaybe MissUSA CallMeMaybe,MissUSA MissUSA GOPConvention Israel MissUSA wolfblitzercnn Doral CelebApprentice TrumpTuesday USOPEN CelebrityApprentice 1 TrumpTuesday CelebrityApprentice GOMITT TrumpTuesday T sayfie,newsmax sayfie,newsmax GOMITT BARACKTAX U GOMITT TheDarkKnightRises,trumpvlog SCAM TrumpTuesday TrumpTuesday 1 tcot Mitt2012,tcot TrumpTuesday trumpvlog trumpvlog trumpvloghttp RomneyRyan2012 TrumpTower TeamRomney MidasTouch TrumpTuesday ...

# %%
from collections import Counter
Counter(hashtag_df['hashtags'])
# Out:
# Counter({'EvanForSI': 1,
#          'TrumpRoast': 4,
#          '1': 112,
#          'Indy500': 1,
#          'trumpvlog': 52,
#          'VEGASusa11,MissUSA': 1,
#          'trumpvlog,celebrityapprenticefinale': 1,
#          'MissUSA,VEGASusa11': 1,
#          'trumpdocumentary': 1,
#          'TeenUSA': 1,
#          'Apprentice': 9,
#          'MissUniverse': 15,
#          'Solyndra': 1,
#          'sparknb': 1,
#          'thedailyshow': 1,
#          'TimeToGetTough': 99,
#          'TImeToGetTough': 2,
#          '1,TimeToGetTough': 2,
#          'TimeToGetTough,1': 1,
#          'TimeToGetToughhttp': 2,
#          'TimeToGet': 1,
#          'C21SuperBowl': 1,
#          'C21': 1,
#          'SuperBowl': 2,
#          'Superbowl': 1,
#          'OneTermFund': 1,
#          'TrumpQandA': 2,
#          'sayfie': 3,
#          'trumpvlog,CelebApprentice': 1,
#          'TrumpQ': 1,
#          'CelebApprentice': 246,
#          'CNNDebate': 5,
#          'Nadarkhani': 4,
#          'Oscars': 26,
#          'pga,golf': 1,
#          'TrumpTuesday': 25,
#          'bluemonsterhttp': 1,
#          'CelebApprentice,Apprentice': 1,
#          'freespeech': 1,
#          'ObamaCare': 6,
#          'TheArtofTheDeal': 6,
#          'CelebApprenticehttp': 2,
#          'CelebApprentice,trumpvlog': 1,
#          'CelebrityApprentice': 116,
#          'rockhall2012': 1,
#          'Success': 5,
#          'rozandmocha': 1,
#          'PainatthePump': 1,
#          'TrumpTowers': 2,
#          'WHCD': 4,
#          'SweepsTweet': 4,
#          'sweepstweet': 15,
#          'NBC,SweepsTweet': 1,
#          'DWTS': 1,
#          'MidasTouch': 4,
#          'DWTS,01': 1,
#          'Mets': 1,
#          'GOP': 9,
#          'CallMeMaybe': 1,
#          'MissUSA': 6,
#          'CallMeMaybe,MissUSA': 1,
#          'GOPConvention': 2,
#          'Israel': 2,
#          'wolfblitzercnn': 1,
#          'Doral': 3,
#          'USOPEN': 1,
#          'GOMITT': 3,
#          'T': 1,
#          'sayfie,newsmax': 2,
#          'BARACKTAX': 1,
#          'U': 1,
#          'TheDarkKnightRises,trumpvlog': 1,
#          'SCAM': 1,
#          'tcot': 7,
#          'Mitt2012,tcot': 1,
#          'trumpvloghttp': 1,
#          'RomneyRyan2012': 1,
#          'TrumpTower': 4,
#          'TeamRomney': 1,
#          'StrongisBeautiful': 1,
#          'TRUMPTUESDAYS': 1,
#          'TRUMPTUESDAY': 2,
#          'TrumpScotland': 3,
#          'WTA': 1,
#          'TRUMP': 20,
#          'trumpvlog,DNC': 1,
#          '10': 1,
#          'Trump': 32,
#          'CPACCO': 2,
#          'Debate,Obama': 1,
#          'VPDebate': 14,
#          '103': 3,
#          'debate': 3,
#          'TruthTour2012': 1,
#          'TRUMPTuesday': 1,
#          'Election2012': 1,
#          'ObamasFavoriteCharity': 1,
#          'obamasfavorite': 1,
#          'Sandy': 3,
#          'HurricaneSandyRelief': 1,
#          'TrumpCares': 1,
#          'Sandy,sandyrelief': 1,
#          'NYE': 1,
#          'SandyRelief': 1,
#          '2': 5,
#          'MIDASTOUCH': 1,
#          'Newtown': 1,
#          'Angels': 1,
#          'Copa': 1,
#          'WGCDoral': 1,
#          'success,truth': 1,
#          'htm,purduecal,accredited': 1,
#          'Trump16': 13,
#          'Trump2016': 380,
#          'dedication,commitment': 1,
#          'yourfired': 1,
#          'theapprentice': 5,
#          'TheApprentice': 10,
#          'JodiArias': 1,
#          'bestshowonTV,yourefired,Trump4Prez': 1,
#          'Trump4Prez': 7,
#          '2013': 1,
#          'wwe': 1,
#          'CelebApprenticeMVP': 1,
#          'CPAC2013': 5,
#          'CPAC': 7,
#          'TrumpDoral': 1,
#          'CPAC13': 1,
#          '3': 3,
#          'genius,Trump2016': 1,
#          'vets': 1,
#          'OpenOurWH': 1,
#          'donthateontheCubes': 1,
#          'respect,jealoushaters': 1,
#          'kimMitchell': 1,
#          '1,winning': 1,
#          'playnice': 1,
#          'conservativepride': 1,
#          'MentionSomebodyYouWantToMeet': 1,
#          'nospoiling': 1,
#          '2016': 29,
#          'EOWDC': 2,
#          'letterman': 1,
#          'preztrump,yourhired': 1,
#          'trumpnationaldoral': 1,
#          'success': 2,
#          'weneedyou': 1,
#          'trumpforpresident': 13,
#          'Letterman': 2,
#          'autismspeaks': 1,
#          'rolemodel': 1,
#          'dissapointment': 1,
#          'inspiration': 2,
#          'CelebApprentice,mba,bestshow': 1,
#          'lovethisman': 1,
#          'WWEHOF,Billionaires': 1,
#          'WWEHOF,WrestleMania': 1,
#          'Redbook': 1,
#          'WWE,wrestlemania': 1,
#          'success,business,life': 1,
#          'celebapprentice': 5,
#          'WWEHOFhttp': 1,
#          'WWEHOF': 17,
#          'TrumpVlog': 5,
#          'WM23,HOF': 1,
#          'ProudToBeAFanOf': 1,
#          'gorgeous': 1,
#          'beentoldtotakealotofballs': 1,
#          'MissUniverse,MissPeru': 1,
#          'HOF': 2,
#          'respect': 1,
#          'theartofthedeal': 2,
#          'masters': 1,
#          'celebrityapprentice,theapprentice': 1,
#          '1,CelebApprentice': 1,
#          'Hawaii': 1,
#          'youvebeentrumped': 2,
#          'love': 2,
#          'menswear': 1,
#          'Quality': 1,
#          'celebapprentice,loveitloveit': 1,
#          'Trumptastic': 1,
#          '19': 1,
#          'waterturbinetopower': 1,
#          'KathyBoudin': 1,
#          'Gotmyvote': 1,
#          'allstar': 1,
#          'MechanicalDog,CelebApprentice': 1,
#          'GreaterInfluence': 1,
#          'cpac': 1,
#          'failed': 1,
#          'getalife': 1,
#          'celebrityapprentice': 10,
#          'unsubscribe': 1,
#          'FundAnything': 5,
#          'FundAnything,Entrepreneurs,GiveBack': 1,
#          'Miami,Doral': 1,
#          'truestory': 1,
#          'REDEYE': 1,
#          'trump,theapprentice': 1,
#          'CNN': 4,
#          'SALUTE': 1,
#          'BEST': 1,
#          'redcross': 1,
#          'troops,Veterans': 1,
#          'TrumpRules': 1,
#          'Donald': 2,
#          'america': 3,
#          'smallbiz,leader': 1,
#          'TheEnd,Perfection': 1,
#          'TrumpUSA': 1,
#          'hope': 1,
#          'YourNotFired': 1,
#          'wantthetrumpfeeling': 1,
#          'timetogettough': 1,
#          'lovethedonald': 1,
#          'thankyou': 1,
#          'YouveMadeIt': 1,
#          'livintheAMERICANdream': 1,
#          'CP5': 1,
#          'MightyPlanes': 2,
#          'Mandela': 1,
#          'CoachLombardi,TrueLeader': 1,
#          'golf': 5,
#          'TimetoGetTough': 1,
#          'Trump2016,zukerisaloser': 1,
#          'trump2016': 43,
#          'whoiszucker': 1,
#          'highlyrecommended': 1,
#          'quality': 1,
#          'Vancouver': 2,
#          'Skywire': 1,
#          'StanleyCup': 3,
#          'Snowden': 1,
#          'askdonald': 1,
#          'Twitter': 1,
#          'SmartGuy': 1,
#          'fact2,kingtrump': 1,
#          'CONCERNED': 1,
#          'iHateTheFactThat,sharkfinsoup': 1,
#          'facepalm': 1,
#          'interested': 1,
#          'DADDY': 1,
#          'classic': 1,
#          'bigtrumpfan': 1,
#          'AskDonnie': 1,
#          'TrumpIn2016': 2,
#          'Greatest': 1,
#          'nyc': 1,
#          'roadhard': 1,
#          'guessnot': 1,
#          'keepingitreal': 1,
#          'nicejob': 1,
#          'RoadHard': 3,
#          'TRUMP4PRES': 1,
#          'BoycottRollingStone': 1,
#          'VAuction': 1,
#          'Chicago,ThankYou': 1,
#          'globalwarming,climatechange': 1,
#          'AnthonyWeiner': 1,
#          'GretaWire': 1,
#          'nobulldonald': 1,
#          'TrumpVine': 2,
#          'Vine': 1,
#          'snowden': 1,
#          'for,2103JuniorPGA': 1,
#          'TrumpNationalDoral': 2,
#          '2013JuniorPGA': 1,
#          'RHONJ': 1,
#          'TBT,Trump': 1,
#          'trumpvine': 1,
#          'Chicago,Trump': 1,
#          'amazing': 1,
#          'ThingBig': 1,
#          'BREAST,CANCER': 1,
#          'Vegas': 2,
#          'momoneymoproblems': 1,
#          'Obama': 3,
#          'votetrump': 1,
#          'RoleModel': 1,
#          'confessionnight': 1,
#          'CEO': 1,
#          'Trump,world,you,are,hired': 1,
#          'CountOnTrump': 1,
#          'MakeItHappen,FixAmerica': 1,
#          'GoodBusinessMove': 1,
#          'TheArtOfTheDeal': 1,
#          'NoWorries': 1,
#          'USA': 7,
#          'RunForPresident': 1,
#          'staytrumping': 1,
#          'TrumpUniversity': 1,
#          '9': 1,
#          'kickhisass': 1,
#          'kidney,donate': 1,
#          'DreamDay': 1,
#          'billionaire,hero': 1,
#          'realsports,trump2016': 1,
#          'SuperstormSandy': 1,
#          'trumptuesdays': 1,
#          'trump': 9,
#          'tellsitlikeitis': 1,
#          'GotMyVote': 2,
#          'Syria': 1,
#          'gratitude,class': 1,
#          'EntrepreneurshipClub': 1,
#          'RAW': 1,
#          'smartestmanalive': 1,
#          'bigfan': 1,
#          'HandsOffSyria': 1,
#          '2016,changeisnear': 1,
#          'shirts,leadership': 1,
#          'autismsupport': 1,
#          'leader': 2,
#          'OldPostOffice': 1,
#          'americans': 1,
#          'TrumpForPresident': 26,
#          'staygreat': 1,
#          'GDNY': 3,
#          'Patriotic': 1,
#          'PEACEOUT': 1,
#          '2103juniorPGA': 1,
#          '2013juniorPGA': 1,
#          'NYFW': 1,
#          'MayweatherCanelo,sohohouse': 1,
#          'youthvote,change,proud': 1,
#          'WM30': 1,
#          'betterwithfriends': 3,
#          'JoinMITeam': 1,
#          'Defund': 1,
#          'Trumpforpresident': 5,
#          'NoDaysOff': 1,
#          'braggingrights': 1,
#          'sharktank': 1,
#          'Raw': 1,
#          'blessings': 1,
#          'RHOBH,CelebApprentice': 1,
#          'totalhack': 1,
#          'Voice,Bible,Survivor,Apprentice': 1,
#          'IDreamofNene': 2,
#          'Obamacare': 15,
#          'MakeDCListen': 5,
#          'MakeDCListen,DefundObamaCare': 1,
#          'MostPowerfulVoiceInMedia': 1,
#          'trump,miley': 1,
#          'TheDonald': 2,
#          'Politicking': 1,
#          'TRUMP2016': 10,
#          'dedication,hardwork': 1,
#          'trueleadership': 1,
#          'tump4prez': 1,
#          'startthemovement': 1,
#          'rydercup': 1,
#          'Davidletterman': 1,
#          'goodguy': 1,
#          'TrumpForChange': 1,
#          'WhatAmericaNeeds,Trump16': 1,
#          'PleaseRun,2016': 2,
#          'all': 1,
#          'Classic': 1,
#          'TRUMP16': 1,
#          'trumpwinery': 1,
#          'youcanthankmelater': 1,
#          'pro': 1,
#          'Darnell': 1,
#          'SignatureCollection': 1,
#          'BillyGraham95,happybirthday': 1,
#          'GQ,Magazine': 1,
#          'tangible,solid,beautiful,artistic,RealEstate': 1,
#          'RealEstate': 1,
#          'PennState,Settlers,SoftTarget': 1,
#          'missuniversehttp': 1,
#          'Trumo2016': 1,
#          'bear': 1,
#          'eagle': 1,
#          'turbinefree': 1,
#          'Levels': 1,
#          'Expo2020': 2,
#          'MissUniverse2013,ThrowBackpic': 1,
#          'FreeSaeed': 1,
#          'savesaeed': 1,
#          'PastorSaeed': 1,
#          'savesaeedpic': 1,
#          'NelsonMandela': 1,
#          'NelsonMandelaMemorial': 1,
#          'LieOfTheYear': 1,
#          'firefightersfordonald': 1,
#          '1,TrumpTower': 1,
#          'TrumpForPresident2016': 2,
#          'freepastorsaeed,AETV': 1,
#          'SaveSaeed': 1,
#          'AskTheDonald': 4,
#          'Macys': 1,
#          'heavenly': 1,
#          'apprenticeaddict': 1,
#          'GOP,TrumpForPresident': 1,
#          'Greatguy': 1,
#          'Trump4President,TRUMP2016': 1,
#          'BlueMonster,Aberdeen,FerryPoint': 1,
#          'NextPresident': 1,
#          'Obamacare,sleepless,nights': 1,
#          'GoldenGlobes': 1,
#          'followtheleader': 1,
#          'confidence,wishihadfiveofthem': 1,
#          'scotland': 1,
#          'NHPolitics': 1,
#          'Hero': 1,
#          'StriveForGreatness': 1,
#          'tbt,throwbackthursday': 1,
#          'NC': 1,
#          'GetKatapulted': 1,
#          'NYGOP': 1,
#          'BeEpic': 1,
#          'doral': 1,
#          'CPAC2014': 3,
#          'RachelMaddow': 1,
#          'YoureFired': 2,
#          'BlueMonster': 5,
#          'TrumpIreland': 1,
#          'TLWorldsBest': 1,
#          'life,fun': 1,
#          'Passion': 1,
#          'trumptie': 1,
#          'Trump,BuzzFeed': 1,
#          'donaldforpresident': 3,
#          'palosverdes': 1,
#          'TrumpForPOTUS': 1,
#          'POTUS': 9,
#          'trumpinternational': 1,
#          'America': 3,
#          'Syracuse': 1,
#          'CPAC2014,askhardquestions': 1,
#          'IloveNY': 1,
#          'Oscars2014': 2,
#          'GoFlashes': 1,
#          'theoscars': 1,
#          'Oscar': 1,
#          'oscars': 3,
#          'muchbetter': 1,
#          'Trump2016,Oscars': 1,
#          '2014Oscars': 1,
#          'LAKEY': 1,
#          'Trump2016,DonaldTrumpsAll': 1,
#          'Oscars,CantStopLaughing,Trump2016': 1,
#          '2,1': 1,
#          'DCBound': 1,
#          'Dubai': 2,
#          'TrumpChicago': 2,
#          'TrumpToronto': 1,
#          'greatman': 1,
#          'cpac2014,cspanwj,cspan': 1,
#          'EPIC': 1,
#          'CNBC': 1,
#          'NewYork,Trump': 1,
#          'BlueForBen': 1,
#          'TIRNYC': 1,
#          'NotHuman': 1,
#          'TeaParty': 2,
#          'betterthanyou': 1,
#          'LIUB': 3,
#          'APC': 1,
#          'thinkbig': 1,
#          'WRESTLEMANIA': 1,
#          'arseniohallshow': 1,
#          'nyma': 1,
#          'your,awesome': 1,
#          'FACT,TRUE': 1,
#          'weneedchange,trumpforpresident': 1,
#          'motivation': 1,
#          'true': 1,
#          'verysmart': 1,
#          'Apple': 1,
#          'trumpcollection,tie,shirt': 1,
#          'TrumpforPres,success,awesomeness': 1,
#          'prayersforJK': 1,
#          'listenup,lovethatguy,businessmind': 1,
#          'therealdeal': 1,
#          'boladagur,gottaloveit': 1,
#          'RunForPresident,2016': 1,
#          'MLB': 1,
#          'luxury,trump': 1,
#          'LikeABoss,BusinessAdvice': 1,
#          'Arnie': 1,
#          'mentor': 1,
#          'realworldsolutions': 1,
#          'Apprentice,CelebrityApprentice': 1,
#          'trumplasvegas': 2,
#          'donaldtrump,TBT': 1,
#          'trumpnationalphiladelphia': 2,
#          'trumpphilly': 1,
#          'BillsMafia': 4,
#          'CashinIn': 1,
#          'tombrady': 1,
#          'NHFreedomSummit': 3,
#          'NHFreedomSummithttp': 1,
#          'BuffaloBills,NewYorkMets,Mets': 1,
#          'NotAChoice': 1,
#          'Hannity': 8,
#          'GOP,president2016': 1,
#          'CliveBundy': 1,
#          'Bills': 2,
#          'Super,Double,Win': 1,
#          'SharkTank': 1,
#          'balmedie': 1,
#          'buytheEagles': 1,
#          'BuffaloBills,WNY': 1,
#          'brilliant': 1,
#          'almostgraduating': 1,
#          'Bills,KeepThemInBuffalo': 1,
#          'GeminisWeAre': 1,
#          'TrumpsBills,billsmafia': 1,
#          'Bills,Buffalove4Life': 1,
#          'GotMyVote,NewAmerica': 1,
#          'FilmForAll': 1,
#          'NFL': 3,
#          'NYTimes': 1,
#          'ThinkBig': 1,
#          'poor': 1,
#          'DonaldTrump': 9,
#          'by': 1,
#          'TrumpForPrez2016': 1,
#          'keepenterprising': 1,
#          'TrumpforPresident': 2,
#          'AutismMayDay,autism': 1,
#          'AKOYA,DAMAC,Trump,Golf,Dubaipic': 1,
#          'Trump,Golf,DAMAC': 1,
#          'betterhappensoon': 1,
#          'RaffaeleSollecito,innocent': 1,
#          'Beautiful,TheBest': 1,
#          'wewantTrump': 1,
#          'USA,TrumpForPresident': 1,
#          'TrumpForPresident,trump2016': 1,
#          'CincoDeMayo,LatinAmerica': 1,
#          'DressLikeABillionaire': 1,
#          'trumpluxury,Doonbeg': 1,
#          'itmustbenumberone': 1,
#          'vancouver': 1,
#          '2016,President': 2,
#          'hole18,Scotland,Trumpgolf': 1,
#          'WineWednesday': 1,
#          'leadership': 1,
#          'whocaroniscalling': 1,
#          'belikeTrump': 1,
#          'NPCLunch': 2,
#          'RLC2014': 1,
#          'NewYorkNY': 1,
#          'Trump2016,2016,prez': 1,
#          'service,amazing,Mrzbirthday': 1,
#          'President2016': 1,
#          'TorontoInternational': 1,
#          'plan,plan': 1,
#          'legends': 1,
#          'OrangeRoom': 1,
#          'GOP2016,Trump2016': 1,
#          'specialheart': 1,
#          'SavetheQueen,MissUSA': 1,
#          'Ghostbusters': 2,
#          'DDay70,WWII': 1,
#          'pleaserun2016': 1,
#          'run2016': 1,
#          'presidentdonaldtrump': 1,
#          'FoxandFriends': 1,
#          'donaldtrump': 1,
#          'TrumpHotel,TrumpTower': 1,
#          'HospitalityConferencehttp': 1,
#          'TrumpEm,Trump4Prez': 1,
#          'President': 5,
#          'forgodssake': 1,
#          'ChicagoSucksAnyway': 1,
#          'TRUMP4PREZ': 1,
#          'VoteDonaldTrump': 1,
#          'trump4president': 2,
#          'TRUMP,Elegance,TrumpChicago': 1,
#          'getalifeRahm': 1,
#          'neworleans,CityBiz': 1,
#          'keepfighting': 1,
#          'Chicago,THEDONALD,TRUMP': 1,
#          'Chicago': 6,
#          'BringBackOurMarine': 4,
#          'JODIEDIXON': 1,
#          'USOpen': 3,
#          'Birthday': 1,
#          'DonaldTrump2016': 1,
#          'Pinehurst': 1,
#          'teamskm': 1,
#          'USOpen,anticlimax': 1,
#          'USOpen,USGA': 1,
#          'Toronto,TheTrumpWay': 1,
#          'HappyFathersDay': 1,
#          'Trump,Chicago': 1,
#          'TrumpForPresident,Trump2016': 3,
#          '2016,TrumpForPresident': 1,
#          'RadioGold': 1,
#          'greatguest': 1,
#          'tweetthetruth,lierlier': 1,
#          'greatservice,besthotel,awesomestaff,luxury': 1,
#          'SiriusXM,DonaldTrump': 1,
#          'knuckleheadsinthemedia': 1,
#          'MDLNY': 1,
#          'zeldinforcongress': 2,
#          'SaveOurMarine': 1,
#          'honesty': 1,
#          'chicagoproud': 1,
#          'bravo,chicagosbest': 1,
#          'Bestchicagosign': 1,
#          'chicago,trumpsign': 1,
#          'Queens10k,funfact': 1,
#          'doubledipping': 1,
#          'Turnberry': 2,
#          'NY1': 1,
#          'Chicago,Trumptower': 1,
#          'Bringbackourmarine': 1,
#          'NothingWrongWithThat': 1,
#          'Barcelona,Europe': 1,
#          'Transformers': 1,
#          'TrumpCarson': 1,
#          'soonplease': 1,
#          '2016,nooptions': 1,
#          'businessgenius': 1,
#          'ThinkLikeAChampion': 1,
#          'trumpinternationaltowerlasvegas': 1,
#          'bestinTheBusiness': 1,
#          'bestcaddieinthebarn': 1,
#          'HeresyourSign,Trump2016,USApic': 1,
#          'American': 1,
#          'FreeOurMarine': 7,
#          'trumpera': 1,
#          'trumprules': 1,
#          'tcot,PJNET': 1,
#          'legend': 1,
#          'MarineHeldinMexico,FREEOURMARINE,Obama': 1,
#          '2016,trumps': 1,
#          'Trump2016,please': 1,
#          'Trumpknowsbest': 1,
#          'HopeForToday': 2,
#          'ManOfThePeople': 1,
#          'PresidentTrump2016': 4,
#          'Donaldtrump,president': 1,
#          'ThinkBigMakeitHappen': 1,
#          'Trumpforprez': 1,
#          'freeourmarine': 1,
#          'please,savethiscountry': 1,
#          'SaveThisCountry': 2,
#          'clean': 1,
#          'donaldtrump,yourefired': 1,
#          'TRUMPforPresident': 1,
#          'BorderCrisis': 1,
#          'breathtaking': 1,
#          'Aberdeenshire': 1,
#          'Legend,Trump': 1,
#          'wearethepeople': 1,
#          'trumpties': 2,
#          'trumpties,trumpshirts': 1,
#          'DonaldTrumpForPresident2016': 1,
#          'amazing,NFL': 1,
#          'sad,damnshame': 1,
#          'Trump,billionaire': 1,
#          'Ebola': 3,
#          'notamuni': 1,
#          'ArtOfTheDeal,ThinkBig': 1,
#          'devastated': 1,
#          'NewThoughtPioneer': 1,
#          'Positive': 1,
#          'USWomensOpen': 7,
#          'quote': 5,
#          'trumpadvice': 1,
#          'POTUS,DC,Congress': 1,
#          'smart': 1,
#          'DTCollection': 1,
#          'trumptower': 2,
#          'PayMyBillsChallenge': 1,
#          'baller': 1,
#          'needtrumpsomehow': 1,
#          'awful': 1,
#          'Emmys': 1,
#          'CDCwhistleblower': 2,
#          'IceBucketChallenge': 5,
#          'ALSIceBucketChallenge,StrikeOutALS': 1,
#          'icebucketchallenge': 1,
#          'SMH,trump2016': 1,
#          '2016election': 2,
#          'coztrumptowersisthebest': 1,
#          'ALS': 2,
#          'DoodleForHunger,Art': 1,
#          'ALSIceBucketChallenge': 4,
#          'Hyperlapse': 1,
#          'ALSIceBucketChallenge,SmackDownALS': 1,
#          'CDCwhistleblower,hearthiswell': 1,
#          'autism,vaccines': 1,
#          'vaccines,Shills,Autism,vaccine': 1,
#          'lodha,trumptower,mumbai': 1,
#          'IfTrumpWerePresident': 1,
#          'RIPJoanRivers': 1,
#          'SaudiArabia': 1,
#          'USA,nowornever': 1,
#          'MuchRespect': 1,
#          'MissUSA,MissAmerica': 1,
#          'nfl': 1,
#          'NFL,refreshing': 1,
#          'BringBackFootball': 1,
#          'NFLestaDepinga': 1,
#          'mikeandmike': 1,
#          'worldisover': 1,
#          'sonsofwrigley': 1,
#          'DancingWiththeStars': 1,
#          'justsayin': 1,
#          'Trumpfan': 1,
#          'takebacksenate': 1,
#          'Wrestlemania4,wrestlemania5': 1,
#          'Trump,golf,Dubai': 1,
#          'PresidentofTweet': 1,
#          'Trump4Prez,FireObama': 1,
#          'trump2016,America': 1,
#          'Thanksgiving,MacysParade': 1,
#          'downtoearthbillionaire': 1,
#          'TBT,ThanksLD': 1,
#          'Forbes400': 1,
#          'nyc,soHo': 1,
#          'gretawire': 1,
#          'MichelinStars': 1,
#          'WIRIGHT': 1,
#          'nhpolitics': 2,
#          'Dallas': 1,
#          'StopTheFlights': 1,
#          'DONALDFORPREZ': 1,
#          'trump4Prez': 1,
#          'NewYorkCity': 1,
#          'ntfm': 1,
#          'iagop,2016': 1,
#          'WIUNION': 1,
#          'saveourcountry': 1,
#          'laguardia,airports': 1,
#          'DonaldTrumpForPresident': 2,
#          'BenBradlee': 1,
#          'HandsOffMyGun': 2,
#          'RIPOscarDeLaRenta': 1,
#          'Trump4President,Trump2016': 2,
#          'BringBackOurMarine,MilitaryMonday': 1,
#          '12,ReadersChoice2014': 1,
#          'yourefired': 1,
#          'hannity': 1,
#          'Trump,President': 1,
#          'trump4potus': 1,
#          'ISIS': 6,
#          'Marine': 1,
#          'Justice': 1,
#          'BestMJPics': 1,
#          'golf,Scotlandpic': 1,
#          'Trump2016,ibelieve': 1,
#          'GASen': 2,
#          'NikWalenda,SkyscraperLive': 1,
#          'golfgem,golfletsgo,golf': 1,
#          'TheCelebrityApprentice': 1,
#          'byeobama': 1,
#          'joanrivers': 1,
#          'favshow': 1,
#          'TriUMPhant': 1,
#          'Trump4President': 4,
#          'Marinefreed': 1,
#          'GOFORIT': 1,
#          'epicmoments': 1,
#          'donaldforprez': 1,
#          'FF': 1,
#          'golf,la': 1,
#          'BlueMonster,TrumpDoralpic': 1,
#          'LIFE': 1,
#          'touristinmyownbackyard,chicago': 1,
#          'philanthropic,Autism': 1,
#          'TP': 1,
#          'TrumpMiami': 1,
#          'Election2014pic': 1,
#          'isis,ebola,obama': 1,
#          'smartwomen': 1,
#          'dailydigs': 1,
#          'luxurytravel': 1,
#          'marinefreed': 1,
#          'VeteransDay': 3,
#          'MarineFreed': 1,
#          'Ayrshire,eat': 1,
#          'LaskerRink': 1,
#          'Doral,White,Golf,Resort': 1,
#          'WomenWhoWork': 1,
#          'Tahmooressi': 1,
#          'AndrewTahmoorissi': 1,
#          'Millennials,pga': 1,
#          'pga14': 1,
#          'pga14annual': 1,
#          'SmackDown,yourefired': 1,
#          'PGA14Annual': 1,
#          'Amazon,1,CelebrityApprentice': 1,
#          'revisitingthefight': 1,
#          'vegas,upgrade': 1,
#          'truth,obama,America': 1,
#          'Thanksgiving': 1,
#          'Chicago,TravelTuesday': 1,
#          'waitingfortrump2016': 1,
#          'CommanderInChief': 1,
#          'TrumpForPresident,2016': 1,
#          'USA,America': 2,
#          'book': 1,
#          'Tump2016': 4,
#          '1,Trump2016': 3,
#          'GYTU': 1,
#          'presidenttrump': 1,
#          'AlSharpton': 1,
#          'Iraq': 1,
#          'CowardInChief,Obummer': 1,
#          'LoveHim': 1,
#          'trumpforpresident,presidenttrump': 1,
#          'homealone2': 1,
#          'NYConf': 2,
#          'Apprentice,GetYourPopcornready': 1,
#          'worldclass': 1,
#          'EricGarner': 1,
#          'nobrainer': 1,
#          'CIA': 1,
#          'TheView': 1,
#          'AKOYA,Oxygen,Dubai': 1,
#          'MSSNG': 1,
#          'StopDividingTheUSA': 1,
#          'JohnRoberts,ObamaTheDestroyer,Conservative': 1,
#          'donaldtrumpforprez': 1,
#          'VancouverProperty,TrumpVancouver': 1,
#          'elected': 1,
#          'MaraLago': 1,
#          'Prez': 2,
#          'Sharknado': 1,
#          'Inspiration': 1,
#          'TortureReport': 1,
#          'US': 1,
#          'Donald,dc,PennAve': 1,
#          'CASEV,Chicago,SheratonChicago': 1,
#          '382LBS,Enforcer': 1,
#          'trumpforpresidemt': 1,
#          'tcot,RedNationRising': 1,
#          'fiscalresponsibility,Trump4President': 1,
#          'rants': 1,
#          'TrumpHolidays': 1,
#          'TortureReport,TRUTH': 1,
#          'SmokeyBearHug': 1,
#          'weneedapatriot,1600pennsylvaniaave,2016,patriotwithabrain': 1,
#          '2016,RealChange': 1,
#          'president,youhavemyVote': 1,
#          'NewYearsEve': 1,
#          'TrumpNewYearsRespic': 1,
#          'TheInterviewMovie': 1,
#          'NoMoreBush': 1,
#          'GoldList2015': 1,
#          'Girlpowerhttp': 1,
#          'trumpsupporter': 2,
#          'CadillacChampionship': 1,
#          '2016Election,USA,NoMoreClintons': 1,
#          'HomeAlone,classic': 1,
#          'Trump2016,TrumpForPresident': 2,
#          'MerryRollTideChristmas': 1,
#          'apprentice': 2,
#          'MerryXmas': 1,
#          'MerryChristmas': 1,
#          'TrumpWinfree2016': 1,
#          'NowReading': 1,
#          '8,TrumpDoral': 1,
#          'holidays,friends,palmbeach,maralago': 1,
#          'JoanRivers': 2,
#          'GoldList2015,nyc,hotel': 1,
#          'excited': 1,
#          'candidate,2016,strong,leaderwho,opinionated,fearless,vote,Trump2016': 1,
#          'WeNeedYou': 2,
#          'epilepsy': 1,
#          'trump16': 1,
#          'lookgoodfeelgoodscangood': 1,
#          'DoubleTrump': 1,
#          'clinton': 1,
#          'TrumpDoral,OrangeBowl,HailState': 1,
#          'trump4pres': 1,
#          'Hasmyrespect': 1,
#          'WinningTicket2016,TrumpCruz2016': 1,
#          'TrumpPOTUS2016,HappyNewYear': 1,
#          'Trumpfan,TrumpForPresident': 1,
#          'HomeAlone2': 1,
#          'saveoursouls': 1,
#          'TVgeek': 1,
#          'Apprentice,excited': 1,
#          'TeamLeeza,CelebApprentice': 2,
#          'TeamLeeza': 3,
#          'getoffmyTV': 1,
#          'unstoppable,makeithappen': 1,
#          'SharkTankNation,Restaurantstartup,theprofit,CelebrityApprentice': 1,
#          'thecelebrityapprentice': 1,
#          'ticktock,ApprenticeNBC': 1,
#          'TeamGilbert': 1,
#          'CelebrityApprentice,thecelebrityapprentice,nbc': 1,
#          'saveSKsocial': 1,
#          'WorkHard,Win': 1,
#          'celebapprentice,askkevin,teamkevin': 1,
#          'TeamKevin': 1,
#          'poorthing,DidYouSeeThat,CelebApprentice': 1,
#          'TeamKevin,AskKevin': 1,
#          'trumpforpresident2016': 1,
#          'catfight,CelebrityApprentice': 1,
#          'TheApprentice,TeamKenya': 1,
#          'truth': 3,
#          'bighead,big,ego': 1,
#          'CelebApprentice,TRUMP': 1,
#          'takeaselfie': 1,
#          'CelebApprentice,datenight': 1,
#          'notlazy': 1,
#          'CelebrityApprentice,CelebApprentice': 1,
#          'CelebApprentice,westcoast': 1,
#          'TeamBrandi': 2,
#          'CelebApprentice,TeamBrandi,TeamKevin': 1,
#          'CelebApprentice,MostIntelligentRealityShow': 1,
#          'CelebrityApprentice,pleasegetfired': 1,
#          'CelebApprentice,CelebrityApprentice,TheApprentice': 1,
#          'goodstuff,yourfired': 1,
#          'CelebApprentice,CelebrityApprentice': 1,
#          'CelebApprentice,NBC': 1,
#          'CelebrityApprentice,foreal': 1,
#          'JustSaying,CelebrityApprentice': 1,
#          'Luvo': 1,
#          'teambrandi': 2,
#          'someonepunchgeraldo': 1,
#          'respect,CelebrityApprentice': 1,
#          'WhereHaveIBeen': 1,
#          'Trump16,Trump16,Trump16,Trump16,Trump16': 1,
#          'trump2016,trump2016,trump2016,trump2016,trump2016,trump2016,trump2016': 1,
#          'TRUMP2016,Work': 1,
#          'JonathanAldridge,DonaldTrump,1,1': 1,
#          '2a': 1,
#          'CelebrityApprentice,Bonding': 1,
#          'Trump2016,Trump4President': 1,
#          'TheDonaldForPres': 1,
#          '2ndamendment': 1,
#          'teamtrump,mrpresident,trump2016': 1,
#          'VoteRed,2016': 1,
#          'runforprez': 1,
#          'DonaldTrump,TheApprentice': 1,
#          'Presidenttrump': 1,
#          'BingeViewer': 2,
#          'DowntonAbbey': 1,
#          'CommonSenseMan': 1,
#          'Miami': 1,
#          'gameplan,RunJohnnyRun,TeamIan': 1,
#          'TeamVortex,TeamInfinity': 1,
#          'favorite,TheApprentice': 1,
#          'prez': 1,
#          'Akoya,Dubai': 1,
#          'BestShowersEver': 1,
#          'CololombiaMissUniverso': 1,
#          'TCA15': 2,
#          'SCTeaParty15': 2,
#          'yourfired,trumprocks': 1,
#          'savior': 1,
#          'YourTimeIsNow': 1,
#          'PatriotsVSColts': 1,
#          'CelebrityApprentice,NBC': 1,
#          'CelebrityApprentice,JoanRivers,CelebApprentice': 1,
#          'donaldtrumprocks': 1,
#          'CelebrityApprentice,lovestowin,willlovetheshoes': 1,
#          'CelebrityApprentice,yourfired': 1,
#          'takenotes': 1,
#          'icon': 1,
#          'ApprenticeNBC': 1,
#          'youlookmarvelous': 1,
#          'CelebApprentice,teambrandi': 1,
#          'celebrityapprenctice,CelebApprentice': 1,
#          'facts': 1,
#          'foxnewsfacts': 1,
#          'SOTU2015': 1,
#          'TrumpVlog,MissUniverse': 1,
#          'SOTU': 3,
#          'MyPassion': 1,
#          'Usa,Colombia': 1,
#          'USA,THAILAND,COLUMBIA,SPAIN,JAMAICA,MissUniverse': 1,
#          'SaveCulzeanpic': 1,
#          'TheBachelor': 2,
#          'great': 1,
#          'SleepyEyes,CelebrityApprentice': 1,
#          '1,TravelersChoice': 1,
#          'RedTiger': 1,
#          'CelebApprentice,Snowmageddon2015': 1,
#          'Donald4Pres': 1,
#          'CelebrityApprentice,GivesHisAll': 1,
#          'whatjusthappened,celebrityapprentice': 1,
#          'rhoa': 1,
#          'DamonKnowsWinning': 1,
#          'WSRingsover90210': 1,
#          'ratings': 1,
#          'justamatteroftime': 1,
#          'Phonegate,CelebApprentice': 2,
#          'CelebrityApprentice,president,teamdonaldtrump': 1,
#          'newyorkpost,tcot': 1,
#          'gotmyvote': 2,
#          '5,TravelersChoice': 1,
#          'YVNCG': 1,
#          'billionare': 1,
#          'tweetgate,celebrityapprentice': 1,
#          'FABULOUS': 1,
#          'Prez,Tump2016': 1,
#          'CelebApprentice,Humor': 1,
#          'CelebApprentice,gonetoosoon': 1,
#          ...})

# %%
dict_data = Counter(hashtag_df['hashtags'])

# WordCloud 생성
from wordcloud import WordCloud, STOPWORDS 
wordcloud = WordCloud(width = 800, height = 800, 
                      background_color ='white', 
                      stopwords = set(STOPWORDS), 
                      max_words=100,
                      max_font_size = 100,
                     ).generate_from_frequencies(dict_data) 
  
# WordCloud 출력                    
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout() 
plt.show()
